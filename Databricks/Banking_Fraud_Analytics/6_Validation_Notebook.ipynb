# %%
# %sql
SELECT * 
FROM banking_bronze.transactions_bronze_tbl;

# %%
# %sql
SELECT * 
FROM banking_silver.transactions_silver_tbl;

# %%
# %sql
select * from banking_silver.dim_customer_silver;

# %%
# %sql
select * from banking_gold.dim_customer_gold_scd1

# %%
# %sql
select * from banking_gold.dim_customer_gold_scd2;

# %%
# %sql
select * from banking_gold.dim_account_gold_scd1;

# %%
# %sql
select * from banking_gold.dim_account_gold_scd2

# %%
# %sql
select *
from banking_gold.fact_account_transactions;

# %%
# %sql
select *
from banking_gold.fact_wide_transactions;
