# %% [markdown]
# **JDBC CONNECTIONS FROM DATABRICKS TO SYNAPSE**

# %%
jdbcUrl = "jdbc:sqlserver://rajeswarisynapse.sql.azuresynapse.net:1433;database=bank_dw"

connectionProperties = {
    "user": "izadmin",
    "password": "Inceptez@123",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
jdbcUrl = "jdbc:sqlserver://rajeswarisynapse.sql.azuresynapse.net:1433;database=bank_dw"

connectionProperties = {
    "user": "izadmin",
    "password": "Inceptez@123",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
spark.table("banking_gold.dim_customer_gold_scd2") \
.write \
.mode("append") \
.jdbc(
    url=jdbcUrl,
    table="dbo.dim_customer_gold_scd2",
    properties=connectionProperties
)

# %%
spark.table("banking_gold.dim_account_gold_scd1") \
.write \
.mode("append") \
.jdbc(
    url=jdbcUrl,
    table="dbo.dim_account_gold_scd1",
    properties=connectionProperties
)

# %%
spark.table("banking_gold.dim_account_gold_scd2") \
.write \
.mode("append") \
.jdbc(
    url=jdbcUrl,
    table="dbo.dim_account_gold_scd2",
    properties=connectionProperties
)

# %%
spark.table("banking_gold.fact_account_transactions") \
.write \
.mode("append") \
.jdbc(
    url=jdbcUrl,
    table="dbo.fact_account_transactions",
    properties=connectionProperties
)

# %%
jdbcUrl = "jdbc:sqlserver://rajeswarisynapse.sql.azuresynapse.net:1433;database=bank_dw"

connectionProperties = {
    "user": "izadmin",
    "password": "Inceptez@123",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
spark.table("banking_gold.fact_wide_transactions") \
.write \
.mode("append") \
.jdbc(
    url=jdbcUrl,
    table="dbo.fact_wide_transactions",
    properties=connectionProperties
)
