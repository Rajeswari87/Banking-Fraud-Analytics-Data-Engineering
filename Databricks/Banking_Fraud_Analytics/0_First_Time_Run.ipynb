# %%
# %sql
CREATE OR REPLACE CONNECTION banking_gcp_mysql_connection
TYPE MYSQL
OPTIONS (
  host '34.174.250.128',
  port '3306',
  user 'inceptez',
  password 'Inceptez@123'
)

# %%
# %sql
CREATE FOREIGN CATALOG if not exists banking_foreign_catalog
USING CONNECTION banking_gcp_mysql_connection;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS banking_bronze;
CREATE SCHEMA IF NOT EXISTS banking_silver;
CREATE SCHEMA IF NOT EXISTS banking_gold;
